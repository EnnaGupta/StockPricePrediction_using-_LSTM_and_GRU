# %%
# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from keras.optimizers import SGD
import math
from sklearn.metrics import mean_squared_error

# %%
# Some functions to help out with
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Real IBM Stock Price')
    plt.plot(predicted, color='blue',label='Predicted IBM Stock Price')
    plt.title('IBM Stock Price Prediction')
    plt.xlabel('Time')
    plt.ylabel('IBM Stock Price')
    plt.legend()
    plt.show()

def return_rmse(test,predicted):
    rmse = math.sqrt(mean_squared_error(test, predicted))
    print("The root mean squared error is {}.".format(rmse))

# %%
# First, we get the data
dataset = pd.read_csv('/content/AABA_2006-01-01_to_2018-01-01.csv', index_col='Date', parse_dates=['Date'])
dataset.head()
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_814451700256494527 = autoviz.get_registered_df('df_814451700256494527')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_814451700256494527, *['Open'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8996203362383865059 = autoviz.get_registered_df('df_8996203362383865059')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_8996203362383865059, *['High'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7845499989415619653 = autoviz.get_registered_df('df_7845499989415619653')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_7845499989415619653, *['Low'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5499311207873363837 = autoviz.get_registered_df('df_5499311207873363837')
#
# def value_plot(df, y, sort_ascending=False, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   if sort_ascending:
#     df = df.sort_values(y).reset_index(drop=True)
#   _, ax = plt.subplots(figsize=figsize)
#   df[y].plot(kind='line')
#   plt.title(y)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(df_5499311207873363837, *['Close'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_2538567387485764103 = autoviz.get_registered_df('df_2538567387485764103')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_2538567387485764103, *['Open'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_5857279931297893246 = autoviz.get_registered_df('df_5857279931297893246')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_5857279931297893246, *['High'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_3299093151189821557 = autoviz.get_registered_df('df_3299093151189821557')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_3299093151189821557, *['Low'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_8356839227161758534 = autoviz.get_registered_df('df_8356839227161758534')
#
# def histogram(df, colname, num_bins=20, figsize=(2, 1)):
#   from matplotlib import pyplot as plt
#   _, ax = plt.subplots(figsize=figsize)
#   plt.hist(df[colname], bins=num_bins, histtype='stepfilled')
#   plt.ylabel('count')
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(df_8356839227161758534, *['Close'], **{})
# chart
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_5983160542001998944 = autoviz.get_registered_df('df_5983160542001998944')
#
# def scatter_plots(df, colname_pairs, scatter_plot_size=2.5, size=8, alpha=.6):
#   from matplotlib import pyplot as plt
#   plt.figure(figsize=(len(colname_pairs) * scatter_plot_size, scatter_plot_size))
#   for plot_i, (x_colname, y_colname) in enumerate(colname_pairs, start=1):
#     ax = plt.subplot(1, len(colname_pairs), plot_i)
#     ax.scatter(df[x_colname], df[y_colname], s=size, alpha=alpha)
#     plt.xlabel(x_colname)
#     plt.ylabel(y_colname)
#     ax.spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = scatter_plots(df_5983160542001998944, *[[['Open', 'High'], ['High', 'Low'], ['Low', 'Close'], ['Close', 'Volume']]], **{})
# chart
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4900290337650683267 = autoviz.get_registered_df('df_4900290337650683267')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_4900290337650683267, *['Low', 'Open', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_2839058726526494691 = autoviz.get_registered_df('df_2839058726526494691')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_2839058726526494691, *['Low', 'High', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_4158012944531042000 = autoviz.get_registered_df('df_4158012944531042000')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_4158012944531042000, *['Low', 'Volume', None], **{})
# chart
# import numpy as np
# from google.colab import autoviz
# df_7400442350687136383 = autoviz.get_registered_df('df_7400442350687136383')
#
# def time_series_multiline(df, timelike_colname, value_colname, series_colname, figsize=(2.5, 1.3), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   palette = list(sns.palettes.mpl_palette(mpl_palette_name))
#   def _plot_series(series, series_name, series_index=0):
#     if value_colname == 'count()':
#       counted = (series[timelike_colname]
#                  .value_counts()
#                  .reset_index(name='counts')
#                  .rename({'index': timelike_colname}, axis=1)
#                  .sort_values(timelike_colname, ascending=True))
#       xs = counted[timelike_colname]
#       ys = counted['counts']
#     else:
#       xs = series[timelike_colname]
#       ys = series[value_colname]
#     plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
#   fig, ax = plt.subplots(figsize=figsize, layout='constrained')
#   df = df.sort_values(timelike_colname, ascending=True)
#   if series_colname:
#     for i, (series_name, series) in enumerate(df.groupby(series_colname)):
#       _plot_series(series, series_name, i)
#     fig.legend(title=series_colname, bbox_to_anchor=(1, 1), loc='upper left')
#   else:
#     _plot_series(df, '')
#   sns.despine(fig=fig, ax=ax)
#   plt.xlabel(timelike_colname)
#   plt.ylabel(value_colname)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = time_series_multiline(df_7400442350687136383, *['Low', 'count()', None], **{})
# chart

# %%
# Checking for missing values
training_set = dataset[:'2016'].iloc[:,1:2].values
test_set = dataset['2017':].iloc[:,1:2].values

# %%
# We have chosen 'High' attribute for prices. Let's see what it looks like
dataset["High"][:'2016'].plot(figsize=(16,4),legend=True)
dataset["High"]['2017':].plot(figsize=(16,4),legend=True)
plt.legend(['Training set (Before 2017)','Test set (2017 and beyond)'])
plt.title('IBM stock price')
plt.show()

# %%
# Scaling the training set
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
# Since LSTMs store long term memory state, we create a data structure with 60 timesteps and 1 output
# So for each element of training set, we have 60 previous training set elements
X_train = []
y_train = []
for i in range(60,2768):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
# Reshaping X_train for efficient modelling
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))

# %%
# The LSTM architecture
regressor = Sequential()
# First LSTM layer with Dropout regularisation
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# Second LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Third LSTM layer
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# Fourth LSTM layer
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
# The output layer
regressor.add(Dense(units=1))

# Compiling the RNN
regressor.compile(optimizer='rmsprop',loss='mean_squared_error')
# Fitting to the training set
regressor.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 85/85 [==============================] - 26s 177ms/step - loss: 0.0139
# Epoch 2/50
# 85/85 [==============================] - 18s 209ms/step - loss: 0.0068
# Epoch 3/50
# 85/85 [==============================] - 13s 152ms/step - loss: 0.0054
# Epoch 4/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0051
# Epoch 5/50
# 85/85 [==============================] - 14s 161ms/step - loss: 0.0043
# Epoch 6/50
# 85/85 [==============================] - 13s 152ms/step - loss: 0.0038
# Epoch 7/50
# 85/85 [==============================] - 15s 175ms/step - loss: 0.0035
# Epoch 8/50
# 85/85 [==============================] - 16s 191ms/step - loss: 0.0033
# Epoch 9/50
# 85/85 [==============================] - 15s 174ms/step - loss: 0.0031
# Epoch 10/50
# 85/85 [==============================] - 15s 171ms/step - loss: 0.0031
# Epoch 11/50
# 85/85 [==============================] - 14s 160ms/step - loss: 0.0028
# Epoch 12/50
# 85/85 [==============================] - 17s 200ms/step - loss: 0.0026
# Epoch 13/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0025
# Epoch 14/50
# 85/85 [==============================] - 12s 143ms/step - loss: 0.0025
# Epoch 15/50
# 85/85 [==============================] - 12s 146ms/step - loss: 0.0023
# Epoch 16/50
# 85/85 [==============================] - 13s 151ms/step - loss: 0.0022
# Epoch 17/50
# 85/85 [==============================] - 12s 146ms/step - loss: 0.0021
# Epoch 18/50
# 85/85 [==============================] - 12s 144ms/step - loss: 0.0021
# Epoch 19/50
# 85/85 [==============================] - 14s 169ms/step - loss: 0.0021
# Epoch 20/50
# 85/85 [==============================] - 12s 144ms/step - loss: 0.0020
# Epoch 21/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0020
# Epoch 22/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0019
# Epoch 23/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0020
# Epoch 24/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0018
# Epoch 25/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0018
# Epoch 26/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0018
# Epoch 27/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0018
# Epoch 28/50
# 85/85 [==============================] - 12s 138ms/step - loss: 0.0017
# Epoch 29/50
# 85/85 [==============================] - 12s 136ms/step - loss: 0.0017
# Epoch 30/50
# 85/85 [==============================] - 12s 139ms/step - loss: 0.0017
# Epoch 31/50
# 85/85 [==============================] - 12s 144ms/step - loss: 0.0016
# Epoch 32/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0016
# Epoch 33/50
# 85/85 [==============================] - 12s 143ms/step - loss: 0.0016
# Epoch 34/50
# 85/85 [==============================] - 12s 146ms/step - loss: 0.0016
# Epoch 35/50
# 85/85 [==============================] - 12s 145ms/step - loss: 0.0016
# Epoch 36/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0015
# Epoch 37/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0015
# Epoch 38/50
# 85/85 [==============================] - 12s 143ms/step - loss: 0.0014
# Epoch 39/50
# 85/85 [==============================] - 12s 141ms/step - loss: 0.0015
# Epoch 40/50
# 85/85 [==============================] - 12s 141ms/step - loss: 0.0015
# Epoch 41/50
# 85/85 [==============================] - 12s 140ms/step - loss: 0.0015
# Epoch 42/50
# 85/85 [==============================] - 12s 137ms/step - loss: 0.0015
# Epoch 43/50
# 85/85 [==============================] - 11s 130ms/step - loss: 0.0015
# Epoch 44/50
# 85/85 [==============================] - 12s 140ms/step - loss: 0.0014
# Epoch 45/50
# 85/85 [==============================] - 12s 140ms/step - loss: 0.0014
# Epoch 46/50
# 85/85 [==============================] - 12s 144ms/step - loss: 0.0014
# Epoch 47/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0013
# Epoch 48/50
# 85/85 [==============================] - 12s 141ms/step - loss: 0.0013
# Epoch 49/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0013
# Epoch 50/50
# 85/85 [==============================] - 12s 142ms/step - loss: 0.0014

# %%
# Now to get the test set ready in a similar way as the training set.
# The following has been done so forst 60 entires of test set have 60 previous values which is impossible to get unless we take the whole
# 'High' attribute data for processing
dataset_total = pd.concat((dataset["High"][:'2016'],dataset["High"]['2017':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 8/8 [==============================] - 2s 34ms/step

# %%
# Visualizing the results for LSTM
plot_predictions(test_set,predicted_stock_price)

# %%
# Evaluating our model
return_rmse(test_set,predicted_stock_price)
# Out:
# The root mean squared error is 3.7600990386344963.

# %%
# The GRU architecture
regressorGRU = Sequential()
# First GRU layer with Dropout regularisation
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Second GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Third GRU layer
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
regressorGRU.add(Dropout(0.2))
# Fourth GRU layer
regressorGRU.add(GRU(units=50, activation='tanh'))
regressorGRU.add(Dropout(0.2))
# The output layer
regressorGRU.add(Dense(units=1))
# Compiling the RNN
regressorGRU.compile(optimizer=SGD(lr=0.01, decay=1e-7, momentum=0.9, nesterov=False),loss='mean_squared_error')
# Fitting to the training set
regressorGRU.fit(X_train,y_train,epochs=50,batch_size=150)
# Out:
# Epoch 1/50
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/gradient_descent.py:114: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)
# 19/19 [==============================] - 13s 320ms/step - loss: 0.0889
# Epoch 2/50
# 19/19 [==============================] - 5s 246ms/step - loss: 0.0458
# Epoch 3/50
# 19/19 [==============================] - 6s 319ms/step - loss: 0.0259
# Epoch 4/50
# 19/19 [==============================] - 5s 249ms/step - loss: 0.0088
# Epoch 5/50
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0036
# Epoch 6/50
# 19/19 [==============================] - 6s 321ms/step - loss: 0.0033
# Epoch 7/50
# 19/19 [==============================] - 5s 252ms/step - loss: 0.0031
# Epoch 8/50
# 19/19 [==============================] - 6s 316ms/step - loss: 0.0029
# Epoch 9/50
# 19/19 [==============================] - 5s 247ms/step - loss: 0.0032
# Epoch 10/50
# 19/19 [==============================] - 5s 244ms/step - loss: 0.0026
# Epoch 11/50
# 19/19 [==============================] - 6s 308ms/step - loss: 0.0028
# Epoch 12/50
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0025
# Epoch 13/50
# 19/19 [==============================] - 6s 311ms/step - loss: 0.0026
# Epoch 14/50
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0024
# Epoch 15/50
# 19/19 [==============================] - 5s 258ms/step - loss: 0.0026
# Epoch 16/50
# 19/19 [==============================] - 6s 310ms/step - loss: 0.0024
# Epoch 17/50
# 19/19 [==============================] - 5s 251ms/step - loss: 0.0024
# Epoch 18/50
# 19/19 [==============================] - 6s 314ms/step - loss: 0.0024
# Epoch 19/50
# 19/19 [==============================] - 5s 245ms/step - loss: 0.0023
# Epoch 20/50
# 19/19 [==============================] - 5s 273ms/step - loss: 0.0024
# Epoch 21/50
# 19/19 [==============================] - 6s 287ms/step - loss: 0.0023
# Epoch 22/50
# 19/19 [==============================] - 5s 268ms/step - loss: 0.0023
# Epoch 23/50
# 19/19 [==============================] - 7s 363ms/step - loss: 0.0024
# Epoch 24/50
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0022
# Epoch 25/50
# 19/19 [==============================] - 6s 335ms/step - loss: 0.0022
# Epoch 26/50
# 19/19 [==============================] - 5s 259ms/step - loss: 0.0022
# Epoch 27/50
# 19/19 [==============================] - 6s 300ms/step - loss: 0.0021
# Epoch 28/50
# 19/19 [==============================] - 6s 320ms/step - loss: 0.0020
# Epoch 29/50
# 19/19 [==============================] - 5s 265ms/step - loss: 0.0021
# Epoch 30/50
# 19/19 [==============================] - 6s 338ms/step - loss: 0.0022
# Epoch 31/50
# 19/19 [==============================] - 5s 266ms/step - loss: 0.0022
# Epoch 32/50
# 19/19 [==============================] - 6s 339ms/step - loss: 0.0021
# Epoch 33/50
# 19/19 [==============================] - 5s 277ms/step - loss: 0.0021
# Epoch 34/50
# 19/19 [==============================] - 7s 358ms/step - loss: 0.0020
# Epoch 35/50
# 19/19 [==============================] - 6s 327ms/step - loss: 0.0019
# Epoch 36/50
# 19/19 [==============================] - 7s 378ms/step - loss: 0.0020
# Epoch 37/50
# 19/19 [==============================] - 6s 290ms/step - loss: 0.0020
# Epoch 38/50
# 19/19 [==============================] - 7s 374ms/step - loss: 0.0020
# Epoch 39/50
# 19/19 [==============================] - 6s 292ms/step - loss: 0.0021
# Epoch 40/50
# 19/19 [==============================] - 6s 342ms/step - loss: 0.0019
# Epoch 41/50
# 19/19 [==============================] - 6s 280ms/step - loss: 0.0021
# Epoch 42/50
# 19/19 [==============================] - 6s 315ms/step - loss: 0.0021
# Epoch 43/50
# 19/19 [==============================] - 6s 332ms/step - loss: 0.0019
# Epoch 44/50
# 19/19 [==============================] - 5s 274ms/step - loss: 0.0020
# Epoch 45/50
# 19/19 [==============================] - 6s 326ms/step - loss: 0.0018
# Epoch 46/50
# 19/19 [==============================] - 5s 253ms/step - loss: 0.0018
# Epoch 47/50
# 19/19 [==============================] - 6s 325ms/step - loss: 0.0019
# Epoch 48/50
# 19/19 [==============================] - 5s 256ms/step - loss: 0.0019
# Epoch 49/50
# 19/19 [==============================] - 5s 279ms/step - loss: 0.0019
# Epoch 50/50
# 19/19 [==============================] - 5s 280ms/step - loss: 0.0019

# %%
# Preparing X_test and predicting the prices
X_test = []
for i in range(60,311):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)
# Out:
# 8/8 [==============================] - 2s 33ms/step

# %%
# Visualizing the results for GRU
plot_predictions(test_set,GRU_predicted_stock_price)

# %%
#Evaluating GRU
return_rmse(test_set,GRU_predicted_stock_price)
# Out:
# The root mean squared error is 2.5199307606135726.

# %% [markdown]
# Although RMSE for GRU is less here but since GRUs have fewer parameters and thus may train a
# bit faster or need less data to generalize. But, with large data, the LSTMs with higher
# expressiveness may lead to better results.
